# %% [markdown]
# # 🔍 Perguntas:
#
# 1. 💰 Qual foi o total de receita gerada no período analisado?
# 2. 🧾 Qual foi o ticket médio por pedido (valor médio gasto por order_id)?
# 3. 🍕 Quais são as pizzas mais vendidas em quantidade?
# 4. 💸 Quais pizzas geraram mais receita total?
# 5. 📆 Em quais datas houve os maiores volumes de vendas?
# 6. 📊 Quais tamanhos de pizza foram mais vendidos?
# 7. 🏷️ Qual categoria de pizza (ex: clássica, vegetariana) gerou mais receita?
# 8. ⏰ Em quais horários do dia ocorrem mais pedidos?
# 9. 🧂 Quais são os ingredientes mais comuns nas pizzas mais populares?
# 10. 🧮 Qual é a média de pizzas vendidas por pedido?

# %% [markdown]
# # ✅ 1. Carregar o CSV no Pandas

# %%
import pandas as pd

# Ler o arquivo CSV
df = pd.read_csv("pizza_sales.csv")

# Ver as primeiras linhas
df.head(5)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0       1.0       1.0     hawaiian_m       1.0   1/1/2015   11:38:36
# 1       2.0       2.0  classic_dlx_m       1.0   1/1/2015   11:57:40
# 2       3.0       2.0  five_cheese_l       1.0   1/1/2015   11:57:40
# 3       4.0       2.0    ital_supr_l       1.0   1/1/2015   11:57:40
# 4       5.0       2.0     mexicana_m       1.0   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %% [markdown]
# # ✅ 2. Criar banco SQLite e carregar o DataFrame

# %%
import sqlite3

# Criar conexão com banco em memória (ou use um arquivo .db se quiser salvar)
conn = sqlite3.connect(":memory:")

# Enviar o DataFrame para o SQLite
df.to_sql("pizza_sales", conn, index=False, if_exists="replace")
# Out:
# 48620

# %%
# Exemplo: total de vendas por tipo de pizza
query = """
SELECT * 
FROM pizza_sales
LIMIT 5;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0       1.0       1.0     hawaiian_m       1.0   1/1/2015   11:38:36
# 1       2.0       2.0  classic_dlx_m       1.0   1/1/2015   11:57:40
# 2       3.0       2.0  five_cheese_l       1.0   1/1/2015   11:57:40
# 3       4.0       2.0    ital_supr_l       1.0   1/1/2015   11:57:40
# 4       5.0       2.0     mexicana_m       1.0   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
print(df.columns)
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
df["order_date"].unique()
# Out:
# array(['1/1/2015', '2/1/2015', '3/1/2015', '4/1/2015', '5/1/2015',
#        '6/1/2015', '7/1/2015', '8/1/2015', '9/1/2015', '10/1/2015',
#        '11/1/2015', '12/1/2015', '13-01-2015', '14-01-2015', '15-01-2015',
#        '16-01-2015', '17-01-2015', '18-01-2015', '19-01-2015',
#        '20-01-2015', '21-01-2015', '22-01-2015', '23-01-2015',
#        '24-01-2015', '25-01-2015', '26-01-2015', '27-01-2015',
#        '28-01-2015', '29-01-2015', '30-01-2015', '31-01-2015', '1/2/2015',
#        '2/2/2015', '3/2/2015', '4/2/2015', '5/2/2015', '6/2/2015',
#        '7/2/2015', '8/2/2015', '9/2/2015', '10/2/2015', '11/2/2015',
#        '12/2/2015', '13-02-2015', '14-02-2015', '15-02-2015',
#        '16-02-2015', '17-02-2015', '18-02-2015', '19-02-2015',
#        '20-02-2015', '21-02-2015', '22-02-2015', '23-02-2015',
#        '24-02-2015', '25-02-2015', '26-02-2015', '27-02-2015',
#        '28-02-2015', '1/3/2015', '2/3/2015', '3/3/2015', '4/3/2015',
# ...

# %% [markdown]
# # 📊 3. EDA com SQL e Python!

# %% [markdown]
# ## -> Qual foi o total de receita gerada no período analisado?

# %%
query = """
SELECT SUM(total_price) AS total_vendas 
FROM pizza_sales;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#    total_vendas
# 0     817860.05

# %% [markdown]
# ## -> Qual foi o ticket médio por pedido (valor médio gasto por order_id)?

# %%
query = """
SELECT SUM(total_price) / COUNT(DISTINCT order_id) AS ticket_medio
FROM pizza_sales;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#    ticket_medio
# 0     38.307262

# %% [markdown]
# ## -> Qual foi o ticket médio por pedido (valor médio gasto por order_id)?

# %%
query = """
SELECT SUM(total_price) AS total_vendas, SUM(total_price) / COUNT(DISTINCT order_id) AS ticket_medio
FROM pizza_sales;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#    total_vendas  ticket_medio
# 0     817860.05     38.307262

# %% [markdown]
# ## -> Quais são as pizzas mais vendidas em quantidade?

# %%
query = """
SELECT DISTINCT pizza_name_id, COUNT(order_id) as quantidade_pedidos
FROM pizza_sales
GROUP BY pizza_name_id
ORDER BY quantidade_pedidos DESC;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#      pizza_name_id  quantidade_pedidos
# 0       big_meat_s                1811
# 1       thai_ckn_l                1365
# 2    five_cheese_l                1359
# 3    four_cheese_l                1273
# 4    classic_dlx_m                1159
# ..             ...                 ...
# 86      mexicana_s                 160
# 87     calabrese_s                  99
# 88   ckn_alfredo_s                  96
# 89  green_garden_l                  94
# 90   the_greek_xxl                  28
#
# [91 rows x 2 columns]

# %% [markdown]
# ## -> Quais pizzas geraram mais receita total?

# %%
query = """
SELECT DISTINCT pizza_name, SUM(total_price) AS total_vendas 
FROM pizza_sales
GROUP BY pizza_name
ORDER BY total_vendas DESC
LIMIT 10;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#                      pizza_name  total_vendas
# 0        The Thai Chicken Pizza      43434.25
# 1    The Barbecue Chicken Pizza      42768.00
# 2  The California Chicken Pizza      41409.50
# 3      The Classic Deluxe Pizza      38180.50
# 4       The Spicy Italian Pizza      34831.25
# 5   The Southwest Chicken Pizza      34705.75
# 6     The Italian Supreme Pizza      33476.75
# 7            The Hawaiian Pizza      32273.25
# 8         The Four Cheese Pizza      32265.70
# 9            The Sicilian Pizza      30940.50

# %%
query = """
SELECT pizza_name, pizza_size, SUM(total_price) AS receita
FROM pizza_sales
GROUP BY pizza_name
ORDER BY receita DESC
LIMIT 10;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#                      pizza_name pizza_size   receita
# 0        The Thai Chicken Pizza          L  43434.25
# 1    The Barbecue Chicken Pizza          S  42768.00
# 2  The California Chicken Pizza          L  41409.50
# 3      The Classic Deluxe Pizza          M  38180.50
# 4       The Spicy Italian Pizza          L  34831.25
# 5   The Southwest Chicken Pizza          L  34705.75
# 6     The Italian Supreme Pizza          L  33476.75
# 7            The Hawaiian Pizza          M  32273.25
# 8         The Four Cheese Pizza          L  32265.70
# 9            The Sicilian Pizza          L  30940.50

# %% [markdown]
# ## -> Quais tamanhos de pizza foram mais vendidos?

# %%
query = """
SELECT pizza_size, SUM(total_price) AS receita
FROM pizza_sales
GROUP BY pizza_size
ORDER BY receita DESC
LIMIT 10;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#   pizza_size    receita
# 0          L  375318.70
# 1          M  249382.25
# 2          S  178076.50
# 3         XL   14076.00
# 4        XXL    1006.60

# %% [markdown]
# ## -> Quais tamanhos de pizza foram mais vendidos?

# %%
query = """
SELECT pizza_category, SUM(total_price) AS receita
FROM pizza_sales
GROUP BY pizza_category
ORDER BY receita DESC
LIMIT 10;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#   pizza_category    receita
# 0        Classic  220053.10
# 1        Supreme  208197.00
# 2        Chicken  195919.50
# 3         Veggie  193690.45

# %% [markdown]
# ## -> Em quais horários do dia ocorrem mais pedidos?

# %%
query = """
SELECT order_time, COUNT(order_id) as quantidade_pedidos
FROM pizza_sales
GROUP BY order_time
ORDER BY quantidade_pedidos DESC
LIMIT 10;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#   order_time  quantidade_pedidos
# 0   12:32:00                  26
# 1   11:59:10                  24
# 2   12:53:29                  23
# 3   12:52:36                  23
# 4   12:26:04                  23
# 5   13:31:27                  21
# 6   12:25:12                  21
# 7   11:57:15                  21
# 8   11:50:01                  21
# 9   13:58:37                  20

# %% [markdown]
# ## -> Quais são os ingredientes mais comuns nas pizzas mais populares?

# %%
query = """
SELECT pizza_ingredients, COUNT(order_id) as quantidade_pedidos
FROM pizza_sales
GROUP BY pizza_ingredients
ORDER BY quantidade_pedidos DESC
LIMIT 10;
"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#                                    pizza_ingredients  quantidade_pedidos
# 0  Pepperoni, Mushrooms, Red Onions, Red Peppers,...                2416
# 1  Barbecued Chicken, Red Peppers, Green Peppers,...                2372
# 2           Sliced Ham, Pineapple, Mozzarella Cheese                2370
# 3                       Mozzarella Cheese, Pepperoni                2369
# 4  Chicken, Pineapple, Tomatoes, Red Peppers, Tha...                2315
# 5  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...                2302
# 6  Coarse Sicilian Salami, Tomatoes, Green Olives...                1887
# 7  Capocollo, Tomatoes, Goat Cheese, Artichokes, ...                1887
# 8  Chicken, Tomatoes, Red Peppers, Red Onions, Ja...                1885
# 9  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...                1850

# %% [markdown]
# ## -> Qual é a média de pizzas vendidas por pedido?

# %%
query = """
SELECT 
SUM(quantity) * 1.0 / COUNT(DISTINCT order_id) AS media_pizzas_por_pedido
FROM pizza_sales;

"""

df_resultado = pd.read_sql_query(query, conn)
df_resultado
# Out:
#    media_pizzas_por_pedido
# 0                 2.321967

# %% [markdown]
# # ✅ 4. Visualização Gráfica dos Dados!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Top 5 Pizzas mais vendidas!

# Realizando a query
query = """
SELECT pizza_name, COUNT(order_id) AS quantidade_pedidos
FROM pizza_sales
GROUP BY pizza_name
ORDER BY quantidade_pedidos DESC
LIMIT 5;
"""

top_pizzas = pd.read_sql_query(query, conn)

# Preparando o plot
plt.figure(figsize=(12, 5))  # gráfico mais compacto
ax = sns.barplot(
    x=top_pizzas["pizza_name"],
    y=top_pizzas["quantidade_pedidos"],
    hue=top_pizzas["pizza_name"],
    palette="dark:skyblue"
)

# Adicionando os valores em cima das barras
for i, v in enumerate(top_pizzas["quantidade_pedidos"]):
    ax.text(i, v + 20, str(int(v)), ha='center', fontsize=10)

# Personalizando o gráfico
plt.title("Top 5 Pizzas Mais Vendidas", fontsize=14)
plt.xlabel("Pizza")
plt.ylabel("Quantidade de Pedidos")
plt.tight_layout()
plt.show()

# %%
# Top 5 Que Mais Geraram Receita!

query = """
SELECT DISTINCT pizza_name, SUM(total_price) AS total_vendas 
FROM pizza_sales
GROUP BY pizza_name
ORDER BY total_vendas DESC
LIMIT 5;
"""

top_pizzas = pd.read_sql_query(query, conn)

# Preparando o plot
plt.figure(figsize=(14, 5))  # gráfico mais compacto
ax = sns.barplot(
    x=top_pizzas["pizza_name"],
    y=top_pizzas["total_vendas"],
    hue=top_pizzas["pizza_name"],
    palette="dark:skyblue",
    legend=False
)

# Adicionando os valores em cima das barras com pontuação
for i, v in enumerate(top_pizzas["total_vendas"]):
    valor_formatado = f"{int(v):,}".replace(",", ".")
    ax.text(i, v + 100, valor_formatado, ha='center', fontsize=10)

# Personalizando o gráfico
plt.title("Top 5 Pizzas que Mais Geraram Receita", fontsize=14)
plt.xlabel("Pizza")
plt.ylabel("Receita Total (R$)")
plt.tight_layout()
plt.show()

# %%
# Top Tamanhos de Pizza Mais Vendidos!

# Realizando a query
query = """
SELECT pizza_size, COUNT(order_id) as quantidade_pedidos
FROM pizza_sales
GROUP BY pizza_size
ORDER BY quantidade_pedidos DESC
"""

top_pizzas = pd.read_sql_query(query, conn)

# Preparando o plot
plt.figure(figsize=(12, 5))  # gráfico mais compacto
ax = sns.barplot(
    x=top_pizzas["pizza_size"],
    y=top_pizzas["quantidade_pedidos"],
    hue=top_pizzas["pizza_size"],
    palette="dark:skyblue"
)

# Adicionando os valores em cima das barras
for i, v in enumerate(top_pizzas["quantidade_pedidos"]):
    ax.text(i, v + 20, str(int(v)), ha='center', fontsize=10)

# Personalizando o gráfico
plt.title("Top Tamanhos de Pizza Mais Vendidos", fontsize=14)
plt.xlabel("Pizza")
plt.ylabel("Quantidade de Pedidos")
plt.tight_layout()
plt.show()

# %%
# Realizando a query
query = """
SELECT mes, COUNT(order_id) as quantidade_pedidos
FROM pizza_sales
GROUP BY mes
ORDER BY mes
"""

pizzas_por_mes = pd.read_sql_query(query, conn)

# Preparando o gráfico de linha
plt.figure(figsize=(10, 5))
ax = sns.lineplot(
    x=pizzas_por_mes["mes"],
    y=pizzas_por_mes["quantidade_pedidos"],
    marker="o",  # adiciona marcadores nos pontos
    color="steelblue"
)

# Adicionando os valores em cima dos pontos
for x, y in zip(pizzas_por_mes["mes"], pizzas_por_mes["quantidade_pedidos"]):
    ax.text(x, y + 10, str(int(y)), ha='center', fontsize=9)

# Personalizando o gráfico
plt.title("Pedidos por Mês", fontsize=14)
plt.xlabel("Mês")
plt.ylabel("Quantidade de Pedidos")
plt.xticks(range(1, 13))  # garante que os meses apareçam de 1 a 12
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🔎 Feature Enginneiring! Adicionando novas colunas com base nas ja existestes!

# %%
# Checar se a coluna order_date ja esta no formato correto
df.dtypes
# Out:
# pizza_id             float64
# order_id             float64
# pizza_name_id         object
# quantity             float64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
# Convertendo de Object para Datetime
df["order_date"] = pd.to_datetime(df["order_date"], format="mixed", dayfirst=True, errors="coerce")

# %%
print(df["order_date"].dtype)
print(df["order_date"].isna().sum())  # quantas datas inválidas foram convertidas em NaT
print(df["order_date"].head())
# Out:
# datetime64[ns]
# 0
# 0   2015-01-01
# 1   2015-01-01
# 2   2015-01-01
# 3   2015-01-01
# 4   2015-01-01
# Name: order_date, dtype: datetime64[ns]

# %%
# Criand novas colunas!
df["ano"] = df["order_date"].dt.year
df["mes"] = df["order_date"].dt.month
df["dia"] = df["order_date"].dt.day
df["dia_semana"] = df["order_date"].dt.day_name()  # Segunda, Terça, etc.

# %%
# Atualizo as colunas no SQL
df.to_sql("pizza_sales", conn, index=False, if_exists="replace")
# Out:
# 48620
